# %%
print("hello")
# Out:
# hello

# %% [markdown]
# # **LABORATORY ACTIVITY 5.1**

# %%
a = 5
print(a)
# Out:
# 5

# %%
#depends how you run it, it will change
print(a)
# Out:
# 10

# %%
a = 7

# %%
print(a)
# Out:
# 7

# %%
a=10
