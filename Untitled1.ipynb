# %% [markdown]
# # **HOA 5.1**

# %% [markdown]
# Task 1.1

# %%
import math, random, platform

# %%
platform.system()
# Out:
# 'Emscripten'

# %%
random.uniform(1,10)
# Out:
# 9.6717122870727

# %%
math.pi
# Out:
# 3.141592653589793

# %%
r = 9.6717122870727
A = math.pi*math.pow(r,2)

# %% [markdown]
# Task 1.2

# %%
# %%writefile my_logic.py
def greet_user(name):
    return f"Hello, {name}! Welcome to CPE009A."
# Out:
# Writing my_logic.py

# %%
from my_logic import greet_user
greet_user(name)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[66], line 1
# ----> 1 from my_logic import greet_user
#       2 greet_user(name)
#
# ModuleNotFoundError: No module named 'my_logic'
