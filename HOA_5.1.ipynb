# %% [markdown]
# # **HOA 5.1**

# %% [markdown]
# Task 1.1

# %%
import math, random, platform

# %%
platform.system()
# Out:
# 'Windows'

# %%
random.uniform(1,10)
# Out:
# 5.768229534208858

# %%
r = 5.768229534208858
A = math.pi*math.pow(r,2)

# %% [markdown]
# Task 1.2

# %%
# %%writefile my_logic.py
def greet_user(name):
    return f"Hello, {name}! Welcome to CPE009A."
# Out:
# Writing my_logic.py

# %%
import my_logic
p = my_logic.greet_user("Pau")
print(p)
# Out:
# Hello, Pau! Welcome to CPE009A.

# %% [markdown]
# Task 1.3

# %%
import os
os.mkdir("calculations")

# %%
os.path.exist("calculations")
# Out:
# True

# %%
# %%writefile file_init_.py
def reddit(name):
    return
# Out:
# UsageError: %%writefile is a cell magic, but the cell body is empty.
